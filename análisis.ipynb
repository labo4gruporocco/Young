# %%
import numpy as np 
import matplotlib.pyplot as plt 
# from nysg_tools import fft 
import scipy as sp

# %%
# cargar fotodiodo

t, V = np.loadtxt("data\measurement_20260611_114030.csv", unpack=True,skiprows=2, delimiter=",")

# no se como va a salir la data del programa lmfao

# %%
#Transformada de fourier; codigo que hice hace como 4 años
