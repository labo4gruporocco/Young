# %%
import numpy as np 
import matplotlib.pyplot as plt 
import nysg_tools as ny 
import scipy as sp

# %%
# cargar fotodiodo

t, V = np.loadtxt("data/fotodiodo.txt", unpack=True)

# no se como va a salir la data del programa lmfao

# %%
#Transformada de fourier; codigo que hice hace como 4 años
freq , spectrum =  ny.fft(t,V)
